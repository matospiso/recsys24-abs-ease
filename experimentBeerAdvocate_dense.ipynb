# %%
import numpy as np
import pandas as pd

from dataset import UserSessionItemDataset
from evaluation import ndcg
from models import EASE, AbsEASE
from pipelines import hyperparameter_selection, run_test

# %%
DATA_FOLDER = "./data/"

df = pd.read_csv(DATA_FOLDER + "ratings_processed_BeerAdvocate_dense.csv")

df.head()
# Out:
#      index  brewery_id              brewery_name   timestamp  rating  \
# 0   662010        3120       Alpine Beer Company  1323364958     1.0
# 1   642923          30     Avery Brewing Company  1314665814     1.0
# 2  1220116           4  Allagash Brewing Company  1322615046     1.0
# 3  1529758          45          Brooklyn Brewery  1322621468     1.0
# 4   456216       23922        Baxter Brewing Co.  1296047711     1.0
#
#    review_aroma  review_appearance       userId  \
# 0           5.0                4.5     01Ryan10
# 1           5.0                4.5     02maxima
# 2           4.0                3.5     02maxima
# 3           4.0                5.0     02maxima
# 4           2.0                3.0  04101Brewer
#
#                        beer_style  review_palate  review_taste  \
# 0                    American IPA            5.0           5.0
# 1  American Double / Imperial IPA            4.5           4.5
# 2         Belgian Strong Dark Ale            4.5           5.0
# 3          Russian Imperial Stout            4.0           4.5
# 4         American Pale Ale (APA)            3.0           2.0
#
#                               beer_name  beer_abv  item_id  \
# 0                              Duet IPA       7.0    27604
# 1                              Maharaja      10.3    22352
# 2  Allagash Black - Bourbon Barrel Aged      10.0    48279
# 3        Brooklyn Black Chocolate Stout      10.0      680
# 4                  Pamola Xtra Pale Ale       4.9    65518
#
#               datetime  sessionId user_session_id  split
# 0  2011-12-08 17:22:38          1      01Ryan10_1  train
# 1  2011-08-30 00:56:54          1      02maxima_1  train
# 2  2011-11-30 01:04:06          1      02maxima_1  train
# 3  2011-11-30 02:51:08          1      02maxima_1  train
# 4  2011-01-26 13:15:11          1   04101Brewer_1  train

# %%
# keep only columns needed for experiments
COLUMNS = ["user_session_id", "item_id", "rating", "split"]
df = df[COLUMNS]

# create user session enconding and item encoding
user_session_id_to_idx = {user_session_id: idx for idx, user_session_id in enumerate(df['user_session_id'].unique())}
user_session_idx_to_id = {idx: user_session_id for user_session_id, idx in user_session_id_to_idx.items()}

item_id_to_idx = {item_id: idx for idx, item_id in enumerate(df['item_id'].unique())}
item_idx_to_id = {idx: item_id for item_id, idx in item_id_to_idx.items()}

# map values to idx using the above dicts
df["user_session_id"] = df["user_session_id"].map(user_session_id_to_idx)
df["item_id"] = df["item_id"].map(item_id_to_idx)

# get number of unique user_sessions and unique items
n_user_sessions = len(user_session_id_to_idx)
n_items = len(item_id_to_idx)

# instantiate dataset
dataset = UserSessionItemDataset(df[df.split == "train"], df[df.split == "val"], df[df.split == "test"], n_user_sessions, n_items)

# %%
# %%capture hypers

l2s = [16., 32., 64., 128., 256., 512., 1024., 2048.]

best_l2s = hyperparameter_selection(dataset, l2s, ndcg, k=100)

# %%
for line in hypers.stdout.split("\n"):
    print(line)
# Out:
# L2 16.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.16374322598078186 +- 0.003923165848542657
# AbsEASE
# ndcg @ 100: 0.1861029930028141 +- 0.00453767528687197
#
# L2 32.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.1709555304144424 +- 0.004064227034488454
# AbsEASE
# ndcg @ 100: 0.18723356492619217 +- 0.004598795872968873
#
# L2 64.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.1790445516188574 +- 0.0041675584362082475
# AbsEASE
# ndcg @ 100: 0.19004799217846247 +- 0.004550288030395654
#
# L2 128.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.18836253778738826 +- 0.004335244883252825
# AbsEASE
# ndcg @ 100: 0.1917965562821817 +- 0.004517371896810434
#
# L2 256.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.1965452735612302 +- 0.004444632874751559
# AbsEASE
# ndcg @ 100: 0.19486430826447637 +- 0.004535735493809437
#
# L2 512.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.2052120042582176 +- 0.004577985914699167
# AbsEASE
# ndcg @ 100: 0.19904058086886844 +- 0.004569130366269468
#
# L2 1024.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.20995263440384457 +- 0.0046723766288828085
# AbsEASE
# ndcg @ 100: 0.20266394519315054 +- 0.004626790056403379
#
# L2 2048.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.209645601195171 +- 0.004682842461505619
# AbsEASE
# ndcg @ 100: 0.20495370738942742 +- 0.00462200647644256
#
# Best L2: EASE 1024.0, AbsEASE 2048.0

# %%
# %%capture results

models = [("EASE", EASE, best_l2s["EASE"][0]), ("AbsEASE", AbsEASE, best_l2s["AbsEASE"][0])]

run_test(models, dataset, ks=[10,20,50,100,200,500])

# %%
for line in results.stdout.split("\n"):
    print(line)
# Out:
# Split test
# EASE
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# pos_inputs
# recall_liked @ 10: 0.041940356629887855 +- 0.0010753213087758707
# recall_disliked @ 10: 0.006823143396721503 +- 0.0011082514761198894
# ndcg @ 10: 0.07935220757522787 +- 0.0015853601449459431
#
# recall_liked @ 20: 0.07152994324476995 +- 0.0014973107869473623
# recall_disliked @ 20: 0.0119123632517146 +- 0.0014253879036190394
# ndcg @ 20: 0.10899195787450193 +- 0.0018747773743765122
#
# recall_liked @ 50: 0.13663367046347247 +- 0.00218687438190656
# recall_disliked @ 50: 0.027797326305385756 +- 0.0021541654859246837
# ndcg @ 50: 0.16112945283040123 +- 0.0023601902955143776
#
# recall_liked @ 100: 0.21320974226380998 +- 0.0028836701502365425
# recall_disliked @ 100: 0.04888382379077256 +- 0.0028963553977615045
# ndcg @ 100: 0.21187378227991427 +- 0.0027891622228585953
#
# recall_liked @ 200: 0.3090758821998297 +- 0.0033807146276031443
# recall_disliked @ 200: 0.08614193987335163 +- 0.0036875890411844983
# ndcg @ 200: 0.2684464027348098 +- 0.003224003283803172
#
# recall_liked @ 500: 0.4616085635318588 +- 0.003824107113645374
# recall_disliked @ 500: 0.1702039348144736 +- 0.005009290352011558
# ndcg @ 500: 0.3479506050925296 +- 0.003822958019641631
#
#
# pos_neg_inputs
# recall_liked @ 10: 0.041196485055573114 +- 0.0010714732432590024
# recall_disliked @ 10: 0.00595623056667077 +- 0.0010520845762506538
# ndcg @ 10: 0.07828462490629286 +- 0.0015655684628107921
#
# recall_liked @ 20: 0.06992790356131275 +- 0.0014566224205111726
# recall_disliked @ 20: 0.011306827078792268 +- 0.0013996101639088894
# ndcg @ 20: 0.10742724483398958 +- 0.0018660908230255888
#
# recall_liked @ 50: 0.1334732354917201 +- 0.002102830900707034
# recall_disliked @ 50: 0.02462241934896835 +- 0.0020239019506005556
# ndcg @ 50: 0.15917230719506056 +- 0.0023362937116714762
#
# recall_liked @ 100: 0.20555163977992458 +- 0.002735420097907478
# recall_disliked @ 100: 0.04607191488789757 +- 0.0028009846676110652
# ndcg @ 100: 0.2082292413408557 +- 0.00280034269642293
#
# recall_liked @ 200: 0.298295816643076 +- 0.00328698290301453
# recall_disliked @ 200: 0.08055379485196042 +- 0.003575213013317174
# ndcg @ 200: 0.2640583174175886 +- 0.0032542753168097664
#
# recall_liked @ 500: 0.447646774166309 +- 0.0038556014869459494
# recall_disliked @ 500: 0.1573653859270242 +- 0.004876242611605587
# ndcg @ 500: 0.3430549196018533 +- 0.0038837945640664627
#
#
#
# AbsEASE
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# pos_inputs
# recall_liked @ 10: 0.04128461074203222 +- 0.0010783627890628565
# recall_disliked @ 10: 0.0060818989142183005 +- 0.001040534837657639
# ndcg @ 10: 0.07726662367313039 +- 0.0015776035964370706
#
# recall_liked @ 20: 0.07026043690447084 +- 0.0014981881373937196
# recall_disliked @ 20: 0.010347970880603631 +- 0.0012945669247204205
# ndcg @ 20: 0.10624456162103076 +- 0.0018600714013239342
#
# recall_liked @ 50: 0.13436332501543075 +- 0.0021915570500163906
# recall_disliked @ 50: 0.025763092152397325 +- 0.0020976043996164596
# ndcg @ 50: 0.15710295076000827 +- 0.002341755120581025
#
# recall_liked @ 100: 0.20973554313920253 +- 0.0028960813343096936
# recall_disliked @ 100: 0.047114626639172236 +- 0.0028516362207076564
# ndcg @ 100: 0.2062264317415581 +- 0.002759501370078606
#
# recall_liked @ 200: 0.3062801894795762 +- 0.0034091797841405203
# recall_disliked @ 200: 0.08159011054371555 +- 0.0035869877035633376
# ndcg @ 200: 0.26271026933607455 +- 0.0031672862763343244
#
# recall_liked @ 500: 0.46260299512061437 +- 0.0038989474271004868
# recall_disliked @ 500: 0.1624756500660674 +- 0.005019359350452467
# ndcg @ 500: 0.3424080725166188 +- 0.0037192395248164703
#
#
# pos_neg_inputs
# recall_liked @ 10: 0.04086429815898347 +- 0.0010555634509721633
# recall_disliked @ 10: 0.005608790783909358 +- 0.0010123095399716363
# ndcg @ 10: 0.07691633399313105 +- 0.001588054755200312
#
# recall_liked @ 20: 0.06859725952285793 +- 0.0014538707720909247
# recall_disliked @ 20: 0.009895401667490061 +- 0.0012777626036514934
# ndcg @ 20: 0.10516570142536331 +- 0.001864747515864194
#
# recall_liked @ 50: 0.13170226602158527 +- 0.0021483728874654062
# recall_disliked @ 50: 0.023459937706723617 +- 0.0020114817797186346
# ndcg @ 50: 0.1558912327008366 +- 0.0023415235259803746
#
# recall_liked @ 100: 0.20199483063995002 +- 0.0028227898682303422
# recall_disliked @ 100: 0.043404205940848865 +- 0.002723001353882305
# ndcg @ 100: 0.20360240507855276 +- 0.002796968769047573
#
# recall_liked @ 200: 0.2967246569234064 +- 0.0033501486328028148
# recall_disliked @ 200: 0.07753356132730706 +- 0.0035571154061361946
# ndcg @ 200: 0.2597540335480282 +- 0.003217836742646288
#
# recall_liked @ 500: 0.4488266051764064 +- 0.00397751553010316
# recall_disliked @ 500: 0.15371068551028802 +- 0.004868352263387757
# ndcg @ 500: 0.33871543824988 +- 0.003794963798924624
#
#
#
# -------------------------------------------

# %%
RESULTS_FOLDER = "./results/beeradvocate_dense/"

with open(RESULTS_FOLDER + "hyperparametersBeerAdvocate_dense.txt", 'w') as f: f.write(hypers.stdout)
with open(RESULTS_FOLDER + "resultsBeerAdvocate_dense.txt", 'w') as f: f.write(results.stdout)
