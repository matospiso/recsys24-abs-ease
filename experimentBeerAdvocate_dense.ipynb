# %%
import numpy as np
import pandas as pd
from scipy.stats import ttest_rel

from dataset import UserSessionItemDataset
from evaluation import ndcg
from models import EASE, AbsEASE
from pipelines import hyperparameter_selection, run_test

# %%
DATA_FOLDER = "./data/beeradvocate/"

df = pd.read_csv(DATA_FOLDER + "ratings_processed_BeerAdvocate_dense.csv")

df.head()
# Out:
#      index  brewery_id              brewery_name   timestamp  rating  \
# 0   662010        3120       Alpine Beer Company  1323364958     1.0
# 1   642923          30     Avery Brewing Company  1314665814     1.0
# 2  1220116           4  Allagash Brewing Company  1322615046     1.0
# 3  1529758          45          Brooklyn Brewery  1322621468     1.0
# 4   456216       23922        Baxter Brewing Co.  1296047711     1.0
#
#    review_aroma  review_appearance       userId  \
# 0           5.0                4.5     01Ryan10
# 1           5.0                4.5     02maxima
# 2           4.0                3.5     02maxima
# 3           4.0                5.0     02maxima
# 4           2.0                3.0  04101Brewer
#
#                        beer_style  review_palate  review_taste  \
# 0                    American IPA            5.0           5.0
# 1  American Double / Imperial IPA            4.5           4.5
# 2         Belgian Strong Dark Ale            4.5           5.0
# 3          Russian Imperial Stout            4.0           4.5
# 4         American Pale Ale (APA)            3.0           2.0
#
#                               beer_name  beer_abv  item_id  \
# 0                              Duet IPA       7.0    27604
# 1                              Maharaja      10.3    22352
# 2  Allagash Black - Bourbon Barrel Aged      10.0    48279
# 3        Brooklyn Black Chocolate Stout      10.0      680
# 4                  Pamola Xtra Pale Ale       4.9    65518
#
#               datetime  sessionId user_session_id  split
# 0  2011-12-08 17:22:38          1      01Ryan10_1  train
# 1  2011-08-30 00:56:54          1      02maxima_1  train
# 2  2011-11-30 01:04:06          1      02maxima_1  train
# 3  2011-11-30 02:51:08          1      02maxima_1  train
# 4  2011-01-26 13:15:11          1   04101Brewer_1  train

# %%
# keep only columns needed for experiments
COLUMNS = ["user_session_id", "item_id", "rating", "split"]
df = df[COLUMNS]

# create user session enconding and item encoding
user_session_id_to_idx = {user_session_id: idx for idx, user_session_id in enumerate(df['user_session_id'].unique())}
user_session_idx_to_id = {idx: user_session_id for user_session_id, idx in user_session_id_to_idx.items()}

item_id_to_idx = {item_id: idx for idx, item_id in enumerate(df['item_id'].unique())}
item_idx_to_id = {idx: item_id for item_id, idx in item_id_to_idx.items()}

# map values to idx using the above dicts
df["user_session_id"] = df["user_session_id"].map(user_session_id_to_idx)
df["item_id"] = df["item_id"].map(item_id_to_idx)

# get number of unique user_sessions and unique items
n_user_sessions = len(user_session_id_to_idx)
n_items = len(item_id_to_idx)

# instantiate dataset
dataset = UserSessionItemDataset(df[df.split == "train"], df[df.split == "val"], df[df.split == "test"], n_user_sessions, n_items)

# %%
# %%capture hypers

l2s = [16., 32., 64., 128., 256., 512., 1024., 2048.]

best_l2s = hyperparameter_selection(dataset, l2s, ndcg, k=100)

# %%
for line in hypers.stdout.split("\n"):
    print(line)
# Out:
# L2 16.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.16374322598078186 +- 0.003923165848542657
# AbsEASE
# ndcg @ 100: 0.1861029930028141 +- 0.00453767528687197
#
# L2 32.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.1709555304144424 +- 0.004064227034488454
# AbsEASE
# ndcg @ 100: 0.18723356492619217 +- 0.004598795872968873
#
# L2 64.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.1790445516188574 +- 0.0041675584362082475
# AbsEASE
# ndcg @ 100: 0.19004799217846247 +- 0.004550288030395654
#
# L2 128.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.18836253778738826 +- 0.004335244883252825
# AbsEASE
# ndcg @ 100: 0.1917965562821817 +- 0.004517371896810434
#
# L2 256.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.1965452735612302 +- 0.004444632874751559
# AbsEASE
# ndcg @ 100: 0.19486430826447637 +- 0.004535735493809437
#
# L2 512.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.2052120042582176 +- 0.004577985914699167
# AbsEASE
# ndcg @ 100: 0.19904058086886844 +- 0.004569130366269468
#
# L2 1024.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.20995263440384457 +- 0.0046723766288828085
# AbsEASE
# ndcg @ 100: 0.20266394519315054 +- 0.004626790056403379
#
# L2 2048.0
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# EASE
# ndcg @ 100: 0.209645601195171 +- 0.004682842461505619
# AbsEASE
# ndcg @ 100: 0.20495370738942742 +- 0.00462200647644256
#
# Best L2: EASE 1024.0, AbsEASE 2048.0

# %%
# %%capture results

models = [("EASE", EASE, best_l2s["EASE"][0]), ("AbsEASE", AbsEASE, best_l2s["AbsEASE"][0])]

results_dict = run_test(models, dataset, ks=[10,20,50,100,200,500])

# %%
for line in results.stdout.split("\n"):
    print(line)
# Out:
# Split test
# EASE
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# pos_inputs
# recall_liked @ 10: 0.042856859668588904 +- 0.0011262059604407345
# recall_disliked @ 10: 0.006757052915668679 +- 0.001044052358177076
# ndcg @ 10: 0.08000378128072888 +- 0.001644242519570384
#
# recall_liked @ 20: 0.07238152375724556 +- 0.0014960748328289653
# recall_disliked @ 20: 0.012997778527758738 +- 0.001456053968559318
# ndcg @ 20: 0.10933966020815296 +- 0.0019122091492103413
#
# recall_liked @ 50: 0.1361698913892164 +- 0.002165306560154339
# recall_disliked @ 50: 0.02639032031759307 +- 0.002044412619774605
# ndcg @ 50: 0.16117662007628497 +- 0.002399797676107992
#
# recall_liked @ 100: 0.20965092269116467 +- 0.0027736308619838368
# recall_disliked @ 100: 0.04976932528266372 +- 0.002758897301383768
# ndcg @ 100: 0.21060788113876486 +- 0.0028219264689291045
#
# recall_liked @ 200: 0.3043265611346986 +- 0.0033288679581603736
# recall_disliked @ 200: 0.08808540439210666 +- 0.0037387803835284765
# ndcg @ 200: 0.26694490975089585 +- 0.003277233997119891
#
# recall_liked @ 500: 0.45929749056552593 +- 0.0038558346010157192
# recall_disliked @ 500: 0.17458699971303357 +- 0.0050346130425083764
# ndcg @ 500: 0.3464874431923103 +- 0.0038677851195907157
#
#
# pos_neg_inputs
# recall_liked @ 10: 0.04232874472062365 +- 0.0011071966919947347
# recall_disliked @ 10: 0.006464218064010299 +- 0.0010099401044988807
# ndcg @ 10: 0.07938023029550359 +- 0.0016128698698693459
#
# recall_liked @ 20: 0.07045988069319209 +- 0.0014493313175243966
# recall_disliked @ 20: 0.012565755745082055 +- 0.0014129824537391221
# ndcg @ 20: 0.10773802384806125 +- 0.0018844640782338586
#
# recall_liked @ 50: 0.13205261695039988 +- 0.0020871714151579467
# recall_disliked @ 50: 0.025217870808145776 +- 0.0019713067668229198
# ndcg @ 50: 0.15892288963537748 +- 0.002371526141648929
#
# recall_liked @ 100: 0.20268008478766383 +- 0.002669885335744042
# recall_disliked @ 100: 0.04562825158487383 +- 0.002615423226876652
# ndcg @ 100: 0.20759928639771694 +- 0.0027996666710096143
#
# recall_liked @ 200: 0.29428928844167657 +- 0.0032734415541157075
# recall_disliked @ 200: 0.08090180878551069 +- 0.003594110125960734
# ndcg @ 200: 0.26301929357712067 +- 0.003282814032001344
#
# recall_liked @ 500: 0.44580754078995544 +- 0.0038670676718707327
# recall_disliked @ 500: 0.16069065735408128 +- 0.004792748406092502
# ndcg @ 500: 0.34200193355731984 +- 0.00390317854828283
#
#
#
# AbsEASE
# Constructing G...
# Density of G: 1.1909%
# Inverting G...
# pos_inputs
# recall_liked @ 10: 0.04183356800704641 +- 0.0011147207261790813
# recall_disliked @ 10: 0.005586123499303158 +- 0.0009310395507315935
# ndcg @ 10: 0.07767042870591305 +- 0.0016343913595003917
#
# recall_liked @ 20: 0.07130294528771457 +- 0.001517903712355057
# recall_disliked @ 20: 0.011527779084857076 +- 0.0013608705895904842
# ndcg @ 20: 0.10666631391258405 +- 0.001912345228279177
#
# recall_liked @ 50: 0.13448979118054188 +- 0.0021692435522456775
# recall_disliked @ 50: 0.02456961817953 +- 0.0019482764703220457
# ndcg @ 50: 0.15725468549518448 +- 0.0023785920439127676
#
# recall_liked @ 100: 0.2085389780841793 +- 0.002778902422020539
# recall_disliked @ 100: 0.04743742848401183 +- 0.0027478415755457773
# ndcg @ 100: 0.20622688420379362 +- 0.002782115717009979
#
# recall_liked @ 200: 0.30436863141578874 +- 0.003404742599506217
# recall_disliked @ 200: 0.08427155304037154 +- 0.0035701146994455723
# ndcg @ 200: 0.2622459734759584 +- 0.0032065016444346663
#
# recall_liked @ 500: 0.4629337138957847 +- 0.003922532227352051
# recall_disliked @ 500: 0.16241688166216156 +- 0.004995557955679532
# ndcg @ 500: 0.3424196933491466 +- 0.0037527893664787756
#
#
# pos_neg_inputs
# recall_liked @ 10: 0.04112399015082197 +- 0.0010948749071756335
# recall_disliked @ 10: 0.005675509187066127 +- 0.0009626105550497899
# ndcg @ 10: 0.07684950453530272 +- 0.0016104849645566036
#
# recall_liked @ 20: 0.07076693771065938 +- 0.001500603780419141
# recall_disliked @ 20: 0.010673954770317828 +- 0.0013005275706509058
# ndcg @ 20: 0.10615274768832346 +- 0.0018906084868218803
#
# recall_liked @ 50: 0.1321566432784991 +- 0.0021173128285486027
# recall_disliked @ 50: 0.02269281953352261 +- 0.0018354648892853417
# ndcg @ 50: 0.15610324493476502 +- 0.0023505690922699836
#
# recall_liked @ 100: 0.20221663118459643 +- 0.0027102301367144645
# recall_disliked @ 100: 0.0449965800804521 +- 0.002662943392146962
# ndcg @ 100: 0.20386219855350401 +- 0.0027861577516262994
#
# recall_liked @ 200: 0.2954327501753537 +- 0.003325387887513839
# recall_disliked @ 200: 0.0797689930759803 +- 0.0035089146499344614
# ndcg @ 200: 0.2592183215285498 +- 0.0032263172145972586
#
# recall_liked @ 500: 0.44879239176847835 +- 0.003969872352822414
# recall_disliked @ 500: 0.15297848938922726 +- 0.004829437996664072
# ndcg @ 500: 0.33873135799424675 +- 0.0038105140908769814
#
#
#
# -------------------------------------------

# %%
# %%capture pvalues

baseline, new_model = models[0][0], models[1][0]
baseline_results, new_model_results = results_dict[baseline], results_dict[new_model]

print("two-sided p-values\n")
for input_type in list(baseline_results.keys()):
    print(input_type)
    for k in list(baseline_results[input_type].keys()):
        for metric in list(baseline_results[input_type][k].keys()):
            if metric.endswith("_values"):
                baseline_values = np.array(baseline_results[input_type][k][metric], dtype=np.float32)
                new_model_values = np.array(new_model_results[input_type][k][metric], dtype=np.float32)
                mean_diff = np.mean(new_model_values - baseline_values)
                p_value = ttest_rel(baseline_values, new_model_values).pvalue

                print(f"{metric} @ {k}: mean(new-baseline) = {mean_diff:.6f} (p={p_value:.6f})")

        print()
    print()
print()

# %%
for line in pvalues.stdout.split("\n"):
    print(line)
# Out:
# two-sided p-values
#
# pos_inputs
# recall_liked_values @ 10: mean(new-baseline) = -0.001023 (p=0.019072)
# recall_disliked_values @ 10: mean(new-baseline) = -0.001171 (p=0.065395)
# ndcg_values @ 10: mean(new-baseline) = -0.002333 (p=0.000010)
#
# recall_liked_values @ 20: mean(new-baseline) = -0.001079 (p=0.044092)
# recall_disliked_values @ 20: mean(new-baseline) = -0.001470 (p=0.105959)
# ndcg_values @ 20: mean(new-baseline) = -0.002673 (p=0.000000)
#
# recall_liked_values @ 50: mean(new-baseline) = -0.001680 (p=0.019711)
# recall_disliked_values @ 50: mean(new-baseline) = -0.001821 (p=0.088775)
# ndcg_values @ 50: mean(new-baseline) = -0.003922 (p=0.000000)
#
# recall_liked_values @ 100: mean(new-baseline) = -0.001112 (p=0.230091)
# recall_disliked_values @ 100: mean(new-baseline) = -0.002332 (p=0.112351)
# ndcg_values @ 100: mean(new-baseline) = -0.004381 (p=0.000000)
#
# recall_liked_values @ 200: mean(new-baseline) = 0.000042 (p=0.971294)
# recall_disliked_values @ 200: mean(new-baseline) = -0.003814 (p=0.072583)
# ndcg_values @ 200: mean(new-baseline) = -0.004699 (p=0.000000)
#
# recall_liked_values @ 500: mean(new-baseline) = 0.003636 (p=0.014298)
# recall_disliked_values @ 500: mean(new-baseline) = -0.012170 (p=0.000020)
# ndcg_values @ 500: mean(new-baseline) = -0.004068 (p=0.000000)
#
#
# pos_neg_inputs
# recall_liked_values @ 10: mean(new-baseline) = -0.001205 (p=0.008486)
# recall_disliked_values @ 10: mean(new-baseline) = -0.000789 (p=0.200836)
# ndcg_values @ 10: mean(new-baseline) = -0.002531 (p=0.000008)
#
# recall_liked_values @ 20: mean(new-baseline) = 0.000307 (p=0.641999)
# recall_disliked_values @ 20: mean(new-baseline) = -0.001892 (p=0.045055)
# ndcg_values @ 20: mean(new-baseline) = -0.001585 (p=0.007263)
#
# recall_liked_values @ 50: mean(new-baseline) = 0.000104 (p=0.899141)
# recall_disliked_values @ 50: mean(new-baseline) = -0.002525 (p=0.030237)
# ndcg_values @ 50: mean(new-baseline) = -0.002820 (p=0.000009)
#
# recall_liked_values @ 100: mean(new-baseline) = -0.000463 (p=0.607715)
# recall_disliked_values @ 100: mean(new-baseline) = -0.000632 (p=0.701594)
# ndcg_values @ 100: mean(new-baseline) = -0.003737 (p=0.000000)
#
# recall_liked_values @ 200: mean(new-baseline) = 0.001143 (p=0.346050)
# recall_disliked_values @ 200: mean(new-baseline) = -0.001133 (p=0.604835)
# ndcg_values @ 200: mean(new-baseline) = -0.003801 (p=0.000000)
#
# recall_liked_values @ 500: mean(new-baseline) = 0.002985 (p=0.037846)
# recall_disliked_values @ 500: mean(new-baseline) = -0.007712 (p=0.007067)
# ndcg_values @ 500: mean(new-baseline) = -0.003271 (p=0.000048)

# %%
RESULTS_FOLDER = "./results/beeradvocate_dense/"

with open(RESULTS_FOLDER + "hyperparametersBeerAdvocate_dense.txt", 'w') as f: f.write(hypers.stdout)
with open(RESULTS_FOLDER + "resultsBeerAdvocate_dense.txt", 'w') as f: f.write(results.stdout)
with open(RESULTS_FOLDER + "pvaluesBeerAdvocate_dense.txt", "w") as f: f.write(pvalues.stdout)
